# %% [markdown]
# NOTE: All urls in this notebook need to be updated. Use data in 'smiles_data_pub_chembl_drugcent.csv' instead.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in .\venv\lib\site-packages (2.1.4)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy<2,>=1.23.2 in .\venv\lib\site-packages (from pandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\venv\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in .\venv\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in .\venv\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in .\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip available: 22.3.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import zipfile

# %%
import pandas as pd # import pandas and use pd as alias

# %%
# retrieve chembl data directly from the web
import requests
chembl_file = requests.get("https://www.ebi.ac.uk/chembl/interface_api/delayed_jobs/outputs/DOWNLOAD-DsRhdLEN2sILkSkr7HGH3DQLqkQIBaje7TwGBSk3Oi8=/DOWNLOAD-DsRhdLEN2sILkSkr7HGH3DQLqkQIBaje7TwGBSk3Oi8=.zip")

# %%
def get_data(url):
    import requests
    import zipfile
    import io
    response = requests.get(url)
    if response.status_code == 200:
        # Reading zip file from requests response
        zip_file = zipfile.ZipFile(io.BytesIO(response.content))
        # Printing file content in zip
        list_of_files = zip_file.namelist()
        print("ZIP file content:")
        for file_name in list_of_files:
            print(file_name)
        # Extracting file from zip
        zip_file.extractall()
        print("Successfully extracted zip file.")
    else:
        print("Failed to download file. Response:", response.status_code)
    return file_name

# %%
chembl_file = get_data("https://www.ebi.ac.uk/chembl/interface_api/delayed_jobs/outputs/DOWNLOAD-DsRhdLEN2sILkSkr7HGH3DQLqkQIBaje7TwGBSk3Oi8=/DOWNLOAD-DsRhdLEN2sILkSkr7HGH3DQLqkQIBaje7TwGBSk3Oi8=.zip")
# Out:
# Failed to download file. Response: 404
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 chembl_file = get_data("https://www.ebi.ac.uk/chembl/interface_api/delayed_jobs/outputs/DOWNLOAD-DsRhdLEN2sILkSkr7HGH3DQLqkQIBaje7TwGBSk3Oi8=/DOWNLOAD-DsRhdLEN2sILkSkr7HGH3DQLqkQIBaje7TwGBSk3Oi8=.zip")
#
# Cell In[5], line 19, in get_data(url)
#      17 else:
#      18     print("Failed to download file. Response:", response.status_code)
# ---> 19 return file_name
#
# UnboundLocalError: cannot access local variable 'file_name' where it is not associated with a value

# %%
chembl_data = pd.read_csv(chembl_file, sep=';')
# inspect few elements on the top of table to check the structure of the table
chembl_data.head()
# Out:
#        ChEMBL ID                      Name  \
# 0  CHEMBL1868702                GESTRINONE
# 1  CHEMBL2106076         CEFPIROME SULFATE
# 2  CHEMBL1446650  MEBEVERINE HYDROCHLORIDE
# 3  CHEMBL3707281         MAGNESIUM LACTATE
# 4  CHEMBL3833409              HYDROTALCITE
#
#                                             Synonyms            Type  \
# 0  A 46 745|A-46-745|A-46745|DIMETRIOSE|GESTRINON...  Small molecule
# 1  CEFPIROME SULFATE|CEFPIROME SULFATE (1:1)|CEFP...  Small molecule
# 2  COLOFAC|COLOFAC 100|COLOFAC IBS|COLOFAC MR|CSA...  Small molecule
# 3  ANHYDROUS MAGNESIUM LACTATE, DL-|DL-LACTIC ACI...  Small molecule
# 4                                       HYDROTALCITE  Small molecule
#
#    Max Phase  Molecular Weight  Targets  Bioactivities  AlogP  \
# 0        4.0            308.42     19.0           61.0   3.72
# 1        4.0            612.67      1.0            1.0  -1.04
# 2        4.0            466.02     15.0           44.0   4.60
# 3        4.0            202.44      NaN            NaN    NaN
# 4        4.0            531.91      NaN            NaN    NaN
#
#    Polar Surface Area  ...  Heavy Atoms  HBA (Lipinski)  HBD (Lipinski)  \
# 0               37.30  ...         23.0             2.0             1.0
# 1              153.92  ...         35.0            11.0             3.0
# 2               57.23  ...         31.0             6.0             0.0
# 3                 NaN  ...          NaN             NaN             NaN
# 4                 NaN  ...          NaN             NaN             NaN
#
#    #RO5 Violations (Lipinski) Molecular Weight (Monoisotopic)  \
# 0                         0.0                        308.1776
# 1                         2.0                        514.1093
# 2                         0.0                        429.2515
# 3                         NaN                        202.0328
# 4                         NaN                        529.9019
#
#    Np Likeness Score  Molecular Species  Molecular Formula  \
# 0               1.86            NEUTRAL           C21H24O2
# 1              -0.19               ACID       C22H24N6O9S3
# 2              -0.60               BASE        C25H36ClNO5
# 3                NaN                NaN          C6H10MgO6
# 4                NaN                NaN      CH16Al2Mg6O19
#
#                                               Smiles  \
# 0  C#C[C@]1(O)CC[C@H]2[C@@H]3CCC4=CC(=O)CCC4=C3C=...
# 1  CO/N=C(\C(=O)N[C@@H]1C(=O)N2C(C(=O)[O-])=C(C[n...
# 2  CCN(CCCCOC(=O)c1ccc(OC)c(OC)c1)C(C)Cc1ccc(OC)c...
# 3               CC(O)C(=O)[O-].CC(O)C(=O)[O-].[Mg+2]
# 4  O=C([O-])[O-].[Al+3].[Al+3].[Mg+2].[Mg+2].[Mg+...
#
#                      Inchi Key
# 0  BJJXHLWLUDYTGC-ANULTFPQSA-N
# 1  RKTNPKZEPLCLSF-QHBKFCFHSA-N
# 2  PLGQWYOULXPJRE-UHFFFAOYSA-N
# 3  OVGXLJDWSLQDRT-UHFFFAOYSA-L
# 4  GDVKFRBCXAPAQJ-UHFFFAOYSA-A
#
# [5 rows x 33 columns]

# %%
# get Smiles column
chembl_data_smiles = chembl_data[['Name', 'Smiles']]
chembl_data_smiles.head()
# Out:
#                        Name                                             Smiles
# 0                GESTRINONE  C#C[C@]1(O)CC[C@H]2[C@@H]3CCC4=CC(=O)CCC4=C3C=...
# 1         CEFPIROME SULFATE  CO/N=C(\C(=O)N[C@@H]1C(=O)N2C(C(=O)[O-])=C(C[n...
# 2  MEBEVERINE HYDROCHLORIDE  CCN(CCCCOC(=O)c1ccc(OC)c(OC)c1)C(C)Cc1ccc(OC)c...
# 3         MAGNESIUM LACTATE               CC(O)C(=O)[O-].CC(O)C(=O)[O-].[Mg+2]
# 4              HYDROTALCITE  O=C([O-])[O-].[Al+3].[Al+3].[Mg+2].[Mg+2].[Mg+...

# %%
# inspect number of rows
chembl_data_smiles.shape
# Out:
# (4192, 2)

# %%
# check if there are any duplicated data
sum(chembl_data_smiles.duplicated(subset='Smiles') == True)
# Out:
# 699

# %%
# drop duplicated data
chembl_smiles = chembl_data_smiles.drop_duplicates(subset='Smiles')
# inspect shape of the data after duplicates removed
chembl_smiles.shape
# Out:
# (3493, 2)

# %%
def get_json_data(url, file_name):
    "Function to retrieve data from pubchem in json format"
    import requests
    res = requests.get(url)
    if res.status_code == 200:
        with open(f'{file_name}.json', 'wb') as json_file:
            json_file.write(res.content)
        print("Successfully downloaded json data")
    else:
        print(f"Failed to download data. Response: {res.status_code}")

# %%
# url from pubchem
json_url = "https://pubchem.ncbi.nlm.nih.gov/sdq/sdqagent.cgi?infmt=json&outfmt=json&query={%22download%22:%22*%22,%22collection%22:%22compound%22,%22where%22:{%22ands%22:[{%22input%22:{%22type%22:%22netcachekey%22,%22idtype%22:%22cid%22,%22key%22:%22M3SV183lqFmfc6pqKBLjQadebD5DsiwkVgE3aE0QJWlNCRk%22}}]},%22order%22:[%22relevancescore,desc%22],%22start%22:1,%22limit%22:10000000,%22downloadfilename%22:%22PubChem_compound_list_M3SV183lqFmfc6pqKBLjQadebD5DsiwkVgE3aE0QJWlNCRk%22}"
# json file name
json_filename = "pubchem_data"

# %%
# don't run this block
# will resulting error contained json

# get_json_data(json_url, json_filename)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 get_json_data(json_url, json_filename)
#
# NameError: name 'get_json_data' is not defined

# %% [markdown]
# NOTE: Pubchem data json dibersihkan secara manual jadi kemungkinan ketika dibaca langsung dengan read json akan terjadi error

# %%
import pandas as pd
# read json data using pandas
pubchem_json = pd.read_json('pubchem_data.json')
pubchem_json.to_csv('pubchem_data.csv')

# %%
pubchem_data = pd.read_csv('pubchem_data.csv')
pubchem_data.head()
# Out:
#    Unnamed: 0  cid                                           cmpdname  \
# 0           0    1                                    Acetylcarnitine
# 1           1    2  1-Propanaminium, 2-(acetyloxy)-3-carboxy-N,N,N...
# 2           2    6                        1-Chloro-2,4-dinitrobenzene
# 3           3   11                                 1,2-Dichloroethane
# 4           4   34                                    2-Chloroethanol
#
#                                          cmpdsynonym      mw          mf  \
# 0  ['Acetyl-DL-carnitine', 'acetylcarnitine', 'DL...  203.24    C9H17NO4
# 1  ['14992-62-2', '[2-(ACETYLOXY)-3-CARBOXYPROPYL...  204.24   C9H18NO4+
# 2  ['1-chloro-2,4-dinitrobenzene', '2,4-Dinitroch...  202.55  C6H3ClN2O4
# 3  ['1,2-dichloroethane', 'Ethylene dichloride', ...   98.96     C2H4Cl2
# 4  ['2-chloroethanol', 'Ethylene chlorohydrin', '...   80.51     C2H5ClO
#
#    polararea  complexity  xlogp  heavycnt  ...  gpfamilycnt  neighbortype  \
# 0       66.4       214.0    0.4        14  ...         1232         2D+3D
# 1       63.6       219.0   -0.3        14  ...         1359         2D+3D
# 2       91.6       224.0    2.3        13  ...         4998         2D+3D
# 3        0.0         6.0    1.5         4  ...         3450         2D+3D
# 4       20.2        10.0   -0.1         4  ...        17847         2D+3D
#
#             meshheadings                                          annothits  \
# 0        Acetylcarnitine  ['Classification', 'Drug and Medication Inform...
# 1                    NaN  ['Biological Test Results', 'Chemical and Phys...
# 2   Dinitrochlorobenzene  ['Biological Test Results', 'Chemical and Phys...
# 3                    NaN  ['Agrochemical Information', 'Biological Test ...
# 4  Ethylene Chlorohydrin  ['Biological Test Results', 'Chemical and Phys...
#
#   annothitcnt    cidcdate                                         sidsrcname  \
# 0           9  2005-06-23  ['3WAY PHARM INC', 'A2B Chem', 'AA BLOCKS', 'A...
# 1           9  2005-06-23  ['001Chemical', '1st Scientific', '3B Scientif...
# 2          14  2005-03-26  ['3B Scientific (Wuhan) Corp', '3WAY PHARM INC...
# 3          17  2004-09-16  ['001Chemical', '1st Scientific', '3B Scientif...
# 4          14  2005-03-26  ['3B Scientific (Wuhan) Corp', 'A2B Chem', 'AA...
#
#                                              depcatg  \
# 0  ['Chemical Vendors', 'Curation Efforts', 'Gove...
# 1  ['Chemical Vendors', 'Curation Efforts', 'Gove...
# 2  ['Chemical Vendors', 'Curation Efforts', 'Gove...
# 3  ['Chemical Vendors', 'Curation Efforts', 'Gove...
# 4  ['Chemical Vendors', 'Curation Efforts', 'Gove...
#
#                                           annotation  \
# 0  ['D002491 - Central Nervous System Agents > D0...
# 1                                                NaN
# 2  ['C308 - Immunotherapeutic Agent > C2139 - Imm...
# 3                                                NaN
# 4                                                NaN
#
#                                                 aids
# 0                                                NaN
# 1                         [781325, 1272365, 1671498]
# 2  [155, 157, 161, 165, 167, 175, 179, 192, 220, ...
# 3  [421, 426, 427, 433, 434, 435, 445, 530, 540, ...
# 4  [256, 1188, 384212, 651631, 651632, 651633, 65...
#
# [5 rows x 41 columns]

# %%
# get smiles data
pubchem_smiles = pubchem_data[['cmpdname', 'canonicalsmiles']]
pubchem_smiles.columns = ['Name', 'Smiles']
pubchem_smiles.head()
# Out:
#                                                 Name  \
# 0                                    Acetylcarnitine
# 1  1-Propanaminium, 2-(acetyloxy)-3-carboxy-N,N,N...
# 2                        1-Chloro-2,4-dinitrobenzene
# 3                                 1,2-Dichloroethane
# 4                                    2-Chloroethanol
#
#                                       Smiles
# 0           CC(=O)OC(CC(=O)[O-])C[N+](C)(C)C
# 1              CC(=O)OC(CC(=O)O)C[N+](C)(C)C
# 2  C1=CC(=C(C=C1[N+](=O)[O-])[N+](=O)[O-])Cl
# 3                                   C(CCl)Cl
# 4                                    C(CCl)O

# %%
pubchem_smiles.head()
# Out:
#                                                 Name  \
# 0                                    Acetylcarnitine
# 1  1-Propanaminium, 2-(acetyloxy)-3-carboxy-N,N,N...
# 2                        1-Chloro-2,4-dinitrobenzene
# 3                                 1,2-Dichloroethane
# 4                                    2-Chloroethanol
#
#                                       Smiles
# 0           CC(=O)OC(CC(=O)[O-])C[N+](C)(C)C
# 1              CC(=O)OC(CC(=O)O)C[N+](C)(C)C
# 2  C1=CC(=C(C=C1[N+](=O)[O-])[N+](=O)[O-])Cl
# 3                                   C(CCl)Cl
# 4                                    C(CCl)O

# %%
# join data from pubchem and chembl
smiles_data = pd.concat([chembl_data_smiles, pubchem_smiles], axis=0)
smiles_data.head()
# Out:
#                        Name                                             Smiles
# 0                GESTRINONE  C#C[C@]1(O)CC[C@H]2[C@@H]3CCC4=CC(=O)CCC4=C3C=...
# 1         CEFPIROME SULFATE  CO/N=C(\C(=O)N[C@@H]1C(=O)N2C(C(=O)[O-])=C(C[n...
# 2  MEBEVERINE HYDROCHLORIDE  CCN(CCCCOC(=O)c1ccc(OC)c(OC)c1)C(C)Cc1ccc(OC)c...
# 3         MAGNESIUM LACTATE               CC(O)C(=O)[O-].CC(O)C(=O)[O-].[Mg+2]
# 4              HYDROTALCITE  O=C([O-])[O-].[Al+3].[Al+3].[Mg+2].[Mg+2].[Mg+...

# %%
# inspect shape of the data after concatenation
smiles_data.shape
# Out:
# (24288, 2)

# %%
# check and delete duplicates
print(f"Number of duplicates: {sum(smiles_data.duplicated(subset='Smiles') == True)}")
smiles_data.drop_duplicates(subset='Smiles', inplace=True)
# inspect data's shape after dropping duplicates
smiles_data.shape
# Out:
# Number of duplicates: 5607
# (18681, 2)

# %%
smiles_data.head()
# Out:
#                        Name                                             Smiles
# 0                GESTRINONE  C#C[C@]1(O)CC[C@H]2[C@@H]3CCC4=CC(=O)CCC4=C3C=...
# 1         CEFPIROME SULFATE  CO/N=C(\C(=O)N[C@@H]1C(=O)N2C(C(=O)[O-])=C(C[n...
# 2  MEBEVERINE HYDROCHLORIDE  CCN(CCCCOC(=O)c1ccc(OC)c(OC)c1)C(C)Cc1ccc(OC)c...
# 3         MAGNESIUM LACTATE               CC(O)C(=O)[O-].CC(O)C(=O)[O-].[Mg+2]
# 4              HYDROTALCITE  O=C([O-])[O-].[Al+3].[Al+3].[Mg+2].[Mg+2].[Mg+...

# %%
# save dulu data hasil bersih2nya
smiles_data.to_csv('smiles_pubchem_chembl.csv')

# %%
def get_tsv_data(url, file_name):
    import requests
    res = requests.get(url)
    if res.status_code == 200:
        with open(f'{file_name}.tsv', 'wb') as tsv_file:
            tsv_file.write(res.content)
        print("Successfully downloaded tsv data.")
    else:
        print("Failed to download tsv data.")

# %%
get_tsv_data("https://unmtid-shinyapps.net/download/DrugCentral/2021_09_01/structures.smiles.tsv", "drugcentral_data")
# Out:
# Successfully downloaded tsv data.

# %%
drugcentral_data = pd.read_table('drugcentral_data.tsv')
drugcentral_data.head()
# Out:
#                                               SMILES  \
# 0  CNC(=O)C1=C(C=C(C=C1)C2=NN3C(=CN=C3N=C2)CC4=CC...
# 1  CC(C)(COC1=CN2C(=C(C=N2)C#N)C(=C1)C3=CN=C(C=C3...
# 2  CCN1C2=CC(=NC=C2C=C(C1=O)C3=CC(=C(C=C3Br)F)NC(...
# 3  C[C@]12CC[C@H]3[C@H]([C@@H]1C[C@H]([C@@H]2O)[1...
# 4      C1=CC2=C(C=C1C3=CN=C(C=C3)[18F])NC4=C2C=NC=C4
#
#                                                InChI  \
# 0  InChI=1S/C23H17FN6O/c1-25-22(31)18-6-5-16(11-1...
# 1  InChI=1S/C29H31N7O3/c1-29(2,37)18-39-24-9-25(2...
# 2  InChI=1S/C24H21BrFN5O2/c1-3-31-21-12-22(27-2)2...
# 3  InChI=1S/C18H23FO2/c1-18-7-6-13-12-5-3-11(20)8...
# 4  InChI=1S/C16H10FN3/c17-16-4-2-11(8-19-16)10-1-...
#
#                       InChIKey    ID                   INN        CAS_RN
# 0  LIOLIMKSCNQPLV-UHFFFAOYSA-N  5392            capmatinib  1029712-80-8
# 1  XIIOFHFUYBLOLW-UHFFFAOYSA-N  5393         selpercatinib  2152628-33-4
# 2  CEFJVGZHQAGLHS-UHFFFAOYSA-N  5394            ripretinib  1442472-39-0
# 3  KDLLNMRYZGUVMA-ZYMZXAKXSA-N  5395  fluoroestradiol F 18    94153-53-4
# 4  GETAAWDSFUCLBS-SJPDSGJFSA-N  5396     flortaucipir F 18  1522051-90-6

# %%
# get name and smiles column
drugcentral_smiles = drugcentral_data[['INN', 'SMILES']]
drugcentral_smiles.columns = ['Name', 'Smiles']
drugcentral_smiles.head()
# Out:
#                    Name                                             Smiles
# 0            capmatinib  CNC(=O)C1=C(C=C(C=C1)C2=NN3C(=CN=C3N=C2)CC4=CC...
# 1         selpercatinib  CC(C)(COC1=CN2C(=C(C=N2)C#N)C(=C1)C3=CN=C(C=C3...
# 2            ripretinib  CCN1C2=CC(=NC=C2C=C(C1=O)C3=CC(=C(C=C3Br)F)NC(...
# 3  fluoroestradiol F 18  C[C@]12CC[C@H]3[C@H]([C@@H]1C[C@H]([C@@H]2O)[1...
# 4     flortaucipir F 18      C1=CC2=C(C=C1C3=CN=C(C=C3)[18F])NC4=C2C=NC=C4

# %%
drugcentral_smiles.shape
# Out:
# (4099, 2)

# %%
# join data with our primary smiles data
smiles_data = pd.concat([smiles_data, drugcentral_smiles], axis=0)
smiles_data.shape
# Out:
# (22780, 2)

# %%
# drop duplicates
print(f"Number of duplicates: {sum(smiles_data.duplicated(subset='Smiles') == True)}")
smiles_data.drop_duplicates(subset='Smiles', inplace=True)
# Out:
# Number of duplicates: 224

# %%
# number of rows after duplicates removed
smiles_data.shape
# Out:
# (22556, 2)

# %%
# save data to csv
smiles_data.to_csv('smiles_data_pub_chembl_drugcent.csv')

# %%
pip install rdkit
# Out:
# Requirement already satisfied: rdkit in .\venv\lib\site-packages (2023.9.2)
# Requirement already satisfied: numpy in .\venv\lib\site-packages (from rdkit) (1.26.2)
# Requirement already satisfied: Pillow in .\venv\lib\site-packages (from rdkit) (10.1.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from rdkit.Chem import PandasTools

# %%
smiles_data.describe()
# Out:
#                     Name                                             Smiles
# count              22534                                              22555
# unique             22455                                              22555
# top     EDETATE DISODIUM  C#C[C@]1(O)CC[C@H]2[C@@H]3CCC4=CC(=O)CCC4=C3C=...
# freq                   2                                                  1

# %%
# TODO: untuk dites
from rdkit.Chem import PandasTools

filenumber = 1
i = 0
batch_size = 1000 

while i < len(smiles_data):
    slc = smiles_data.iloc[i:i+batch_size, :]
    try:
        PandasTools.AddMoleculeColumnToFrame(slc, 'Smiles', 'Molecule', includeFingerprints=True)
        PandasTools.WriteSDF(slc, f'./sdf/smiles_data{filenumber}.sdf', molColName='Molecule', idName='Name')
        filenumber += 1
    except Exception as e:
        print(f"Failed to write batch-{filenumber}: {e.args[0]}")
        break
    finally:
        i += batch_size
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 from rdkit.Chem import PandasTools
#       3 filenumber = 1
#       4 i = 0
#
# File d:\belajar_fastapi\venv\Lib\site-packages\rdkit\__init__.py:35
#      33   if kernel_name == 'ZMQInteractiveShell' or module_name == 'google.colab._shell':
#      34     logger.info("Enabling RDKit %s jupyter extensions" % __version__)
# ---> 35     from rdkit.Chem.Draw import IPythonConsole
#      36     rdBase.LogToPythonStderr()
#      37 except Exception:
#
# File d:\belajar_fastapi\venv\Lib\site-packages\rdkit\Chem\Draw\__init__.py:22
#      20 from rdkit.Chem import rdDepictor
#      21 from rdkit.Chem.Draw import rdMolDraw2D
# ---> 22 from rdkit.Chem.Draw.MolDrawing import DrawingOptions
#      23 from rdkit.Chem.Draw.MolDrawing import MolDrawing
#      24 from rdkit.Chem.Draw.rdMolDraw2D import *
#
# File <frozen importlib._bootstrap>:1178, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1140, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:1080, in _find_spec(name, path, target)
#
# File <frozen importlib._bootstrap_external>:1504, in find_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1476, in _get_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1645, in find_spec(self, fullname, target)
#
# File <frozen importlib._bootstrap_external>:161, in _path_isfile(path)
#
# File <frozen importlib._bootstrap_external>:153, in _path_is_mode_type(path, mode)
#
# File <frozen importlib._bootstrap_external>:147, in _path_stat(path)
#
# KeyboardInterrupt:

# %%
from rdkit.Chem import PandasTools

filenumber = 1
i = 0
batch_size = 1000 

while i < len(smiles_data):
    slc = smiles_data.iloc[i:i+batch_size, :]
    try:
        PandasTools.AddMoleculeColumnToFrame(slc, 'Smiles', 'Molecule', includeFingerprints=True)
        PandasTools.WriteSDF(slc, f'./sdf/smiles_data{filenumber}.sdf', molColName='Molecule', idName='Name')
        filenumber += 1
    except Exception as e:
        print(f"Failed to write batch-{filenumber}: {e.args[0]}")
        break
    finally:
        i += batch_size
# Out:
# Failed to write batch-1: No registered converter was able to produce a C++ rvalue of type class std::basic_string<wchar_t,struct std::char_traits<wchar_t>,class std::allocator<wchar_t> > from this Python object of type float
# d:\belajar_fastapi\venv\Lib\site-packages\rdkit\Chem\PandasTools.py:373: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame[molCol] = frame[smilesCol].map(
# d:\belajar_fastapi\venv\Lib\site-packages\rdkit\Chem\PandasTools.py:373: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame[molCol] = frame[smilesCol].map(
# [17:13:06] WARNING: not removing hydrogen atom without neighbors
# [17:13:06] WARNING: not removing hydrogen atom without neighbors
# d:\belajar_fastapi\venv\Lib\site-packages\rdkit\Chem\PandasTools.py:373: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame[molCol] = frame[smilesCol].map(
# d:\belajar_fastapi\venv\Lib\site-packages\rdkit\Chem\PandasTools.py:373: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame[molCol] = frame[smilesCol].map(
# d:\belajar_fastapi\venv\Lib\site-packages\rdkit\Chem\PandasTools.py:373: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame[molCol] = frame[smilesCol].map(
# [17:13:14] Explicit valence for atom # 1 Si, 8, is greater than permitted
# [17:13:14] Explicit valence for atom # 1 Si, 8, is greater than permitted
# [17:13:14] Explicit valence for atom # 3 Si, 8, is greater than permitted
# [17:13:14] Explicit valence for atom # 1 Si, 8, is greater than permitted
# [17:13:15] WARNING: not removing hydrogen atom without neighbors
# [17:13:15] WARNING: not removing hydrogen atom without neighbors
# d:\belajar_fastapi\venv\Lib\site-packages\rdkit\Chem\PandasTools.py:373: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame[molCol] = frame[smilesCol].map(
# Failed to write batch-6: Python argument types in
#     Mol.__init__(Mol, NoneType)
# did not match C++ signature:
#     __init__(struct _object * __ptr64, class RDKit::ROMol mol, bool quickCopy=False, int confId=-1)
#     __init__(struct _object * __ptr64, class std::basic_string<char,struct std::char_traits<char>,class std::allocator<char> > pklString, unsigned int propertyFlags)
#     __init__(struct _object * __ptr64, class std::basic_string<char,struct std::char_traits<char>,class std::allocator<char> > pklString)
#     __init__(struct _object * __ptr64)
# [17:13:19] WARNING: not removing hydrogen atom without neighbors
# [17:13:19] WARNING: not removing hydrogen atom without neighbors
# d:\belajar_fastapi\venv\Lib\site-packages\rdkit\Chem\PandasTools.py:373: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame[molCol] = frame[smilesCol].map(
# [17:13:21] WARNING: not removing hydrogen atom without neighbors
# [17:13:21] WARNING: not removing hydrogen atom without neighbors
# [17:13:21] WARNING: not removing hydrogen atom without neighbors
# [17:13:21] WARNING: not removing hydrogen atom without neighbors
# [17:13:21] WARNING: not removing hydrogen atom without neighbors
# [17:13:22] WARNING: not removing hydrogen atom without neighbors
# [17:13:22] WARNING: not removing hydrogen atom without neighbors
# [17:13:22] WARNING: not removing hydrogen atom without neighbors
# [17:13:22] WARNING: not removing hydrogen atom without neighbors
# [17:13:22] WARNING: not removing hydrogen atom without neighbors
# [17:13:22] WARNING: not removing hydrogen atom without neighbors
# [17:13:22] WARNING: not removing hydrogen atom without neighbors
# [17:13:22] WARNING: not removing hydrogen atom without neighbors
# [17:13:22] WARNING: not removing hydrogen atom without neighbors
# [17:13:22] WARNING: not removing hydrogen atom without neighbors
# [17:13:22] WARNING: not removing hydrogen atom without neighbors
# [17:13:22] WARNING: not removing hydrogen atom without neighbors
# [17:13:22] WARNING: not removing hydrogen atom without neighbors
# [17:13:23] WARNING: not removing hydrogen atom without neighbors
# [17:13:23] WARNING: not removing hydrogen atom without neighbors
# d:\belajar_fastapi\venv\Lib\site-packages\rdkit\Chem\PandasTools.py:373: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame[molCol] = frame[smilesCol].map(
# [17:13:26] WARNING: not removing hydrogen atom without neighbors
# [17:13:26] WARNING: not removing hydrogen atom without neighbors
# [17:13:26] WARNING: not removing hydrogen atom without neighbors
# [17:13:27] WARNING: not removing hydrogen atom without neighbors
# d:\belajar_fastapi\venv\Lib\site-packages\rdkit\Chem\PandasTools.py:373: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame[molCol] = frame[smilesCol].map(
# d:\belajar_fastapi\venv\Lib\site-packages\rdkit\Chem\PandasTools.py:373: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame[molCol] = frame[smilesCol].map(
# [17:13:37] Explicit valence for atom # 1 Si, 8, is greater than permitted
# d:\belajar_fastapi\venv\Lib\site-packages\rdkit\Chem\PandasTools.py:373: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame[molCol] = frame[smilesCol].map(
# Failed to write batch-10: Python argument types in
#     Mol.__init__(Mol, NoneType)
# did not match C++ signature:
#     __init__(struct _object * __ptr64, class RDKit::ROMol mol, bool quickCopy=False, int confId=-1)
#     __init__(struct _object * __ptr64, class std::basic_string<char,struct std::char_traits<char>,class std::allocator<char> > pklString, unsigned int propertyFlags)
#     __init__(struct _object * __ptr64, class std::basic_string<char,struct std::char_traits<char>,class std::allocator<char> > pklString)
#     __init__(struct _object * __ptr64)
# [17:13:41] WARNING: not removing hydrogen atom without neighbors
# [17:14:21] WARNING: not removing hydrogen atom without neighbors
# [17:14:21] WARNING: not removing hydrogen atom without neighbors
# [17:14:21] WARNING: not removing hydrogen atom without neighbors
# [17:14:21] WARNING: not removing hydrogen atom without neighbors
# d:\belajar_fastapi\venv\Lib\site-packages\rdkit\Chem\PandasTools.py:373: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fr
SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame[molCol] = frame[smilesCol].map(
# [17:15:39] WARNING: not removing hydrogen atom without neighbors
# [17:15:39] WARNING: not removing hydrogen atom without neighbors
# [17:15:39] WARNING: not removing hydrogen atom without neighbors
# [17:15:51] WARNING: not removing hydrogen atom without neighbors
# [17:15:51] WARNING: not removing hydrogen atom without neighbors
# [17:16:01] WARNING: not removing hydrogen atom without neighbors
# [17:16:01] WARNING: not removing hydrogen atom without neighbors
# [17:16:03] Explicit valence for atom # 28 Cl, 2, is greater than permitted
# [17:16:03] WARNING: not removing hydrogen atom without neighbors
# [17:16:03] WARNING: not removing hydrogen atom without neighbors
# [17:16:03] WARNING: not removing hydrogen atom without neighbors
# [17:16:03] WARNING: not removing hydrogen atom without neighbors
# [17:16:04] WARNING: not removing hydrogen atom without neighbors
# [17:16:04] WARNING: not removing hydrogen atom without neighbors
# d:\belajar_fastapi\venv\Lib\site-packages\rdkit\Chem\PandasTools.py:373: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame[molCol] = frame[smilesCol].map(
# Failed to write batch-13: Python argument types in
#     Mol.__init__(Mol, NoneType)
# did not match C++ signature:
#     __init__(struct _object * __ptr64, class RDKit::ROMol mol, bool quickCopy=False, int confId=-1)
#     __init__(struct _object * __ptr64, class std::basic_string<char,struct std::char_traits<char>,class std::allocator<char> > pklString, unsigned int propertyFlags)
#     __init__(struct _object * __ptr64, class std::basic_string<char,struct std::char_traits<char>,class std::allocator<char> > pklString)
#     __init__(struct _object * __ptr64)
# [17:16:51] WARNING: not removing hydrogen atom without neighbors
# [17:16:51] WARNING: not removing hydrogen atom without neighbors
# [17:16:51] WARNING: not removing hydrogen atom without neighbors
# [17:16:55] WARNING: not removing hydrogen atom without neighbors
# [17:16:55] WARNING: not removing hydrogen atom without neighbors
# [17:16:55] WARNING: not removing hydrogen atom without neighbors
# [17:17:05] WARNING: not removing hydrogen atom without neighbors
# [17:17:05] WARNING: not removing hydrogen atom without neighbors
# [17:17:05] WARNING: not removing hydrogen atom without neighbors
# [17:17:05] WARNING: not removing hydrogen atom without neighbors
# [17:17:05] WARNING: not removing hydrogen atom without neighbors
# [17:17:05] WARNING: not removing hydrogen atom without neighbors
# [17:17:05] WARNING: not removing hydrogen atom without neighbors
# [17:17:05] WARNING: not removing hydrogen atom without neighbors
# [17:17:05] WARNING: not removing hydrogen atom without neighbors
# [17:17:05] WARNING: not removing hydrogen atom without neighbors
# [17:17:05] WARNING: not removing hydrogen atom without neighbors
# [17:17:06] WARNING: not removing hydrogen atom without neighbors
# [17:17:06] WARNING: not removing hydrogen atom without neighbors
# [17:17:06] WARNING: not removing hydrogen atom without neighbors
# [17:17:07] WARNING: not removing hydrogen atom without neighbors
# [17:17:07] WARNING: not removing hydrogen atom without neighbors
# [17:17:07] WARNING: not removing hydrogen atom without neighbors
# [17:17:07] WARNING: not removing hydrogen atom without neighbors
# [17:17:07] WARNING: not removing hydrogen atom without neighbors
# [17:17:07] WARNING: not removing hydrogen atom without neighbors
# [17:17:11] WARNING: not removing hydrogen atom without neighbors
# [17:17:11] WARNING: not removing hydrogen atom without neighbors
